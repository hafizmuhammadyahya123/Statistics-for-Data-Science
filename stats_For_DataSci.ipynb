# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizmuhammadyahya123/Statistics-for-Data-Science/blob/main/stats_For_DataSci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ARTHIMATIC MEAN:
# import lib
import pandas as pd
import numpy as np
import seaborn as sns

df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
sns.histplot(df,x='fare')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# GEOMETRIC MEAN
from scipy import stats
data = np.arange(10,50)

stats.gmean(data)
# Out:
# np.float64(26.95308903244783)

# %%
# HARMONIC MEAN
from scipy import stats
data = np.arange(10,70)

stats.hmean(data)
# Out:
# np.float64(30.157076307728637)

# %%
from scipy import stats
data = np.array([10,20,30,40,50])

stats.trim_mean(data,0.05)  #0.05 = 20% (After Trim[20,30,40]) Truncated mean = (20+30+40)/3
# Out:
# np.float64(30.0)

# %%
# Range: Range = Max-Min
# lets find of a data
import numpy as np
df = np.array([10,20,30,40,50])

np.ptp(df) #Range Formula from numpy
# Out:
# np.int64(40)

# %%
# MEDIAN
import numpy as np
df = np.array([20,30,40,200]) #with outlier

MedianWitOutlier = np.median(df)
print(MedianWitOutlier)

import numpy as np
df = np.array([20,30,40]) #without outlier

MedianWithoutOutlier = np.median(df)
print(MedianWithoutOutlier)
# Out:
# 35.0
# 30.0

# %%
# MEAN
import numpy as np

df = np.array([20,30,40,200]) #with outlier

mean_with_outlier = np.mean(df)
print(mean_with_outlier)

# Big impact

import numpy as np

df = np.array([20,30,40]) #without outlier

mean_without_outlier = np.mean(df)
print(mean_without_outlier)
# Out:
# 72.5
# 30.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# generating a data set with potential outliers
np.random.seed(0)
data = np.random.normal(100,20,200)
data = np.append(data, [300,5])  #Adding potential outliers

# calculating IQR
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)

IQR = Q3 - Q1


# Definig the outlier criteria (1.5 times the IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identifying outliers
outliers = (data < lower_bound) | (data > upper_bound)

# Removing outliers
data_no_outliers = data[~outliers]

# ploting the original data after with outliers
plt.figure(figsize=(14, 6))
plt.subplot(1,2,1)
sns.boxplot(data=data)
plt.title('original data with outliers')

# ploting the data after removing outlier
plt.subplot(1,2,2)
sns.boxplot(data=data_no_outliers)
plt.title('Data After Removing Outliers')

plt.show()

# %% [markdown]
# # Topic Data Distribution And Its Type

# %%
# import required lib
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
# load  data set from seaborn
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(8)
histogram_con_data = sns.histplot(data=df, x='total_bill',kde=True)
histogram_con_data
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Discrete data use Binomial Distribution
plt.figure(8)
sns.histplot(data=df,x='size',kde=True)
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
plt.figure(8)
sns.histplot(data=df,x='smoker',kde=True) #categorical pr distribution nahi bnti jesy yahan bnanay ki
                                         # koshish ki but ye koe distribution nahi ha
# Out:
# <Axes: xlabel='smoker', ylabel='Count'>

# %%
plt.figure(8)
sns.histplot(data=df, x='sex', kde=True) #categorical pr distribution nahi bnti jesy yahan bnanay ki
                                         # koshish ki but ye koe distribution nahi ha
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
plt.figure(8)
sns.histplot(data=df, x='day', kde=True) #categorical pr distribution nahi bnti jesy yahan bnanay ki
                                         # koshish ki but ye koe distribution nahi ha
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
plt.figure(8)
sns.histplot(data=df, x='tip', kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# load titanic data
import seaborn as sns
df_01 = sns.load_dataset('titanic')
df_01.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data=df_01, x='age', kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df_01, x='fare', kde=True, bins=50, hue = 'pclass')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data=df_01, x='age', kde=True, bins=50, hue = 'class')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df_01, x='age', kde=True, bins=50, hue='who')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### STATISTICS PRACTICAL IMPLEMENTATION WITH PYTHON

# %%
# CLACULATE MEAN WITH NUMPY
AgesWithoutOutlier = [22,30,34,35,39,45,48,50,51,54,56] #pascal case vari
ages_with_outlier =  [22,30,34,35,39,45,48,50,51,54,56,160] #snake case vari
import numpy as np

Mean = np.mean(AgesWithoutOutlier)
mean = np.mean(ages_with_outlier)
print(Mean)
print("Big impact with outlier",mean)

# similarly

# Calculate mean with Stats
import statistics
mean = statistics.mean(AgesWithoutOutlier)
Mean = statistics.mean(ages_with_outlier)

print(mean)
print("Big impact with outlier",Mean)
# Out:
# 42.18181818181818
# Big impact with outlier 52.0
# 42.18181818181818
# Big impact with outlier 52

# %%
# calculate median with numpy
import numpy as np
Median = np.median(AgesWithoutOutlier)
median = np.median(ages_with_outlier)

print(Median)
print("Minor impact with outlier",median)

# similarly

# calculate median with stat
import statistics
Median = statistics.median(AgesWithoutOutlier)
median = statistics.median(ages_with_outlier)

print(Median)
print("Minor impact with outlier",median)
# Out:
# 45.0
# Minor impact with outlier 46.5
# 45
# Minor impact with outlier 46.5

# %%
import seaborn as sns
sns.boxplot(ages_with_outlier)
# Out:
# <Axes: >

# %% [markdown]
# # 5 Number summary

# %%
import numpy as np
q1,q3 = np.percentile(ages_with_outlier,[25,75])

print("25_PERCENTILE =" , q1 , "75_PERCENTILE =",q3)
# Out:
# 25_PERCENTILE = 34.75 75_PERCENTILE = 51.75

# %%
# to check outlier lower & uper bound
IQR = q3 - q1

outlier = 1.5 * IQR
print(outlier)

lower_bound = q1 - 1.5 * IQR

upper_bound = q3 + 1.5 * IQR

print("LOWER BOUND =", lower_bound, "UPPER BOUND =", upper_bound)
# Out:
# 25.5
# LOWER BOUND = 9.25 UPPER BOUND = 77.25

# %% [markdown]
# # MEASURE OF DISPERSION
#
# # 1) VARIENCE
# # 2) DISPERSION

# %%
import statistics
variance_from_stat = statistics.variance(ages_with_outlier)
print(variance_from_stat)

# DIFFERENCE B/W

import numpy as np
variance_from_numpy = np.var(ages_with_outlier, axis=0) #np.variance use sample variance mtlb degree of freedom reason ha
print(variance_from_numpy)
# Out:
# 1265.4545454545455
# 1160.0

# %% [markdown]
# # OVER ALL PRACTICE FOR COVER TOPIC FROM STATISTICS

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Arthematic Mean
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
sns.histplot(x='fare', data=df)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
from scipy import stats
data = [12,20,30,39,49]
geometric_mean = stats.gmean(data)
geometric_mean
# Out:
# np.float64(26.774331530710743)

# %%
data_with_outlier = [12,20,30,39,49,150]
GeometricMean = stats.gmean(data_with_outlier)
GeometricMean
# Out:
# np.float64(35.6818536067218)

# %%
# median through the numpy
median = np.median(data_with_outlier)
print(median)

median = np.median(data) #without outlier
print(median)
# Out:
# 34.5
# 30.0

# %%
# median through the statistics
import statistics
median_without_outlier = statistics.median(data)
print(median)

median_with_outlier = statistics.median(data_with_outlier)
print(median_with_outlier)
# Out:
# 30.0
# 34.5

# %%
# MEAN
# mean through the numpy
arithmetic_mean = np.mean(data)
print(arithmetic_mean)

# GM through the stats
geometric_mean = stats.gmean(data)
print(geometric_mean)

# HM through the stats
harmonic_mean = stats.hmean(data)
print(harmonic_mean)

#--------------------------------------#

# MEDIAN
# median through the numpy
median = np.median(data)
print(median)

# median through the stats
median = statistics.median(data)
print(median)
# Out:
# 30.0
# 26.774331530710743
# 23.505535055350556
# 30.0
# 30

# %%
import numpy as np
from scipy import stats
import statistics

# AM with numpy
data = [11,22,34,66,77]
mean = np.mean(data)
print(mean)

# AM with statistics
mean = statistics.mean(data)
print(mean)

# GM With statistics
GM = statistics.geometric_mean(data)
print(GM)
# similarly
GM = stats.gmean(data)
print(GM)

# HM with Statistics
HM = statistics.harmonic_mean(data)
print(HM)
# similarly
HM = stats.hmean(data)
print(HM)

# median without outlier
median_with_numpy = np.median(data)
print(median)
# similarly
median_with_statistics = statistics.median(data)
print(median)

# median_through_the_numpy
MyData = [10,24,34,39,49,50,150]
MedianWithOutlier = np.median(MyData)
MedianWithOutlier
# Out:
# 42.0
# 42
# 33.439963039259624
# 33.439963039259624
# 25.78463558765594
# 25.784635587655945
# 34.0
# 34.0

# %%
from re import M
import numpy as np
from scipy import stats
import statistics

MyDataWithOutlier = [11,20,29,40,50,65,150]
MyDataWithoutOutlier = [11,20,29,40,50,65]

# using numpy
# Mean
mean = np.mean(MyDataWithoutOutlier)
print(mean)
# BIG IMPACT
mean = np.mean(MyDataWithOutlier)
print(mean)

# using statistics
# mean
mean_through_the_statistics = statistics.mean(MyDataWithoutOutlier)
print(mean_through_the_statistics)
# BIG IMPACT
mean_through_the_statistics = statistics.mean(MyDataWithOutlier)
print(mean_through_the_statistics)

# using statistics
# GM
GM = statistics.geometric_mean(MyDataWithoutOutlier)
print(GM)
# BIG IMPACT
GM = statistics.geometric_mean(MyDataWithOutlier)
print(GM)

# using statistics
# HM
HM = statistics.harmonic_mean(MyDataWithOutlier)
print(HM)

HM = statistics.harmonic_mean(MyDataWithoutOutlier)
print(HM)

# median using numpy
median = np.median(MyDataWithOutlier)
print(median)

median = np.median(MyDataWithoutOutlier)
print(median)

# median using statistics
median = statistics.median(MyDataWithOutlier)
print(median)

median = statistics.median(MyDataWithoutOutlier)
print(median)
# Out:
# 35.833333333333336
# 52.142857142857146
# 35.833333333333336
# 52.142857142857146
# 30.65213092073216
# 38.4573475533351
# 28.87275029962851
# 25.447832556902732
# 40.0
# 34.5
# 40
# 34.5

# %% [markdown]
# # KURTOSIS AND AGE

# %%
import seaborn as sns
from scipy import stats

df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# find kurtosis of age
stats.kurtosis(df['age'], fisher=False) #fisher=False means adjustment / fisher test
# Out:
# np.float64(nan)
